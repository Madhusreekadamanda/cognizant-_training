# %%
list = [1,2,3]
print(list)
# Out:
# [1, 2, 3]

# %%
string = ("madhu")
print(string)
# Out:
# madhu

# %%
name = ["madhu","sree","kadamanda"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# madhu
# sree
# kadamanda

# %%
list = [122,34,47,55]
it=iter(list)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 122
# 34
# 47
# 55

# %%
name = ["tommy","minni"]
it = iter(name)
print(next(it))
# Out:
# tommy

# %%
name = ["tommy","minni"]
it = iter(name)
print(next(it))
print(next(it))
# Out:
# tommy
# minni

# %%
file = open("demo.txt","w")
file.write("hellooo")
file.close

file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hellooo

# %%
file = open("demo.txt","w")
file.write("hellooo")

file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hellooo

# %%
file = open("demo.txt","w")
file.write("hellooo")
file.close

file = open("demo.txt","w")
file.write("hey world")

file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hey world

# %%
file = open("demo.txt","w")
file.write("hellooo")
file.close

file = open("demo.txt","r")
content = file.read()
print(content)

    
file = open("demo.txt","w")
file.write("hey chotu")

file = open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hellooo
# hey chotu
