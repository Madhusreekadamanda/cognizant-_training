# %%
list = [1,2,3,4]
print(list[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 list = [1,2,3,4]
# ----> 2 print(list[5])
#
# IndexError: list index out of range

# %%
list = [1,2,3,4]
print(list[3])
# Out:
# 4

# %%
num = 5
print(num/0)
print("last line of the program")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[77], line 2
#       1 num = 5
# ----> 2 print(num/0)
#       3 print("last line of the program")
#
# ZeroDivisionError: division by zero

# %%
num = 10
print(num/2)
print("last line of the program")
# Out:
# 5.0
# last line of the program

# %%
try:
    num = 10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    file = open("xyz.txt","r")
except FileNotFoundError:
    print("file doesn't exist")
# Out:
# file doesn't exist

# %%
try:
    age = int(input("enter your age:"))
except FileNotFound:
    print("enter the valid age")
# Out:
# enter your age: 15

# %%
try:
    age = int(input("enter your age:"))
    if age<15:
        raise ValueErrortry:
    age ("this age is not valid")
        
except ValueError as ve:
    print("this age is not valid")
# Out:
#   Cell In[82], line 4
#     raise ValueErrortry:
#                        ^
# SyntaxError: invalid syntax

# %%
try:
    age = int(input("enter your age:"))
    if age<15:
        raise ValueError("this age is not valid")
        
except ValueError as ve:
    print("this age is not valid")
# Out:
# enter your age: 12
# this age is not valid

# %%
try:
    age = int(input("enter your age:"))
    if age<15:
        raise ValueError("this age is not valid")   
        
except ValueError as ve:
    print("this age is not valid")
else:
    print("age is vaild")
# Out:
# enter your age: 20
# age is vaild

# %%
try:
    course = (input("your course is"))
except FileNotFoundError:
    print("your course is")
# Out:
# your course is bba

# %%
try:
    int(input("enter the number"))
    print(20/num)
except ValueError:
    print("enter the number")
# Out:
# enter the number 5
# 2.0

# %%
try:
    int(input("enter the number"))
    print(2/num)
except ValueError:
    print("please enter the number")
# Out:
# enter the number 2
# 0.4

# %%
try:
    course = (input("your course is"))
except FileNotFoundError:
    print("your course is")
# Out:
# your course is bcs

# %%
try:
    course = (input("your name is"))
except FileNotFoundError:
    print("your course is")
# Out:
# your name is madhu

# %%
try:
    mobile = input("enter your brand")
except StringError:
    print("abc")
# Out:
# enter your brand narzo

# %%
try:
     m    
except StringError:
    print("your brand is")
# Out:
#   Cell In[89], line 1
#     try:except StringError:
#         ^
# SyntaxError: invalid syntax
