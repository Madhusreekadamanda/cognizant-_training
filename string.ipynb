# %%
class Person:
    def __init__(self ,name ,age):
        self.name = name
        self.age = age
        
p1= Person("manu" ,20)
p2= Person("cherry" ,20)
p3= Person("rohini" ,21)
print(p1.name)
print(p1.age)
print(p2.name)
print(p2.age)
print(p3.name)
print(p3.age)
# Out:
# manu
# 20
# cherry
# 20
# rohini
# 21

# %% [markdown]
# name = "madhu"
# print(name)

# %%
city = ("jagtial")
print(city[3])
# Out:
# t

# %%
city = ("karimnagar")
print(city[-2])
# Out:
# a

# %%
city = ("karimnagar")
print(city[1:5])
# Out:
# arim

# %%
s = "hello"
print("hello" *3)
# Out:
# hellohellohello

# %%
m = "hello"
print("hello " *4)
# Out:
# hello hello hello hello

# %%
name = ("karimnagar")
print(name[0:8:1])
# Out:
# karimnag

# %%
name = ("madhu")
print(name.upper())
# Out:
# MADHU

# %%
name = "MADHU"
print(name.lower())
# Out:
# madhu

# %%
city = "hello jagtial"
print(city.replace("hello" , "welcome"))
# Out:
# welcome jagtial

# %%
m = "kadamanda nagaraju"
print(m.find("nagaraju"))
# Out:
# 10

# %%
name = input("enter the name :")
print("hello", name)
# Out:
# enter the name : madhusree
# hello madhusree

# %%
m = "madhu"
print(m [::-1])
# Out:
# uhdam

# %%
name = input("enter the name")
college = input("enter the college")
course = input("enter")
print("joined", college)
# Out:
# enter the name madhu
# enter the college alphores
# enter bsc
# joined alphores

# %%
name = input("enter the name")
colege = input("enter the college")
print("welcome", name +" to ", college)
# Out:
# enter the name madhusree
# enter the college awdc
# welcome madhusree to  alphores

# %%
name = "madhu"
def greet():
    print("hello",name)
greet()
# Out:
# hello madhu

# %%
name = "madhu"
def welcome():
    print("heii",name)
welcome()
# Out:
# heii madhu

# %%
def add(a,b):
    return a+b
print(add(10,30))
# Out:
# 40

# %%
def add(a,b,c=0):
    return a+b+c
print(add(5,6))
print(add(11,20,10))
# Out:
# 11
# 41

# %%
def multiplication(a,b,c):
    return a*b*c
print(multiplication(2,3,4))
# Out:
# 24

# %%
def multiplication(a,b,c=1):
    return a*b*c
print(multiplication(2,2,3))  
print(multiplication(5,5))
# Out:
# 12
# 25

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def student(*marks):
    print(sum(marks))
student(10,20)
student(10,20,30)
student(10,20,30)
# Out:
# 30
# 60
# 60
