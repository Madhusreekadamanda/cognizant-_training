# %%
class person:
    def __init__(self ,name ,age):
        self.name=name
        self.age=age

    def myfunc(self):
        print("hello my name is " + self.name)

p1 = person("arun",26)
p1 .myfunc()
# Out:
# hello my name is arun

# %%
class car:
    name = "bmw"
    colour = "blue"
    
car1 = car
print(car1.name)
print(car1.colour)
# Out:
# bmw
# blue

# %%
class phone:
    name = "realme"
    model = "narzo"

phone1 = phone
print(phone1.name)
print(phone1.model)
# Out:
# realme
# narzo

# %%
class marks:
    name = "sandhya"
    score = "89"

marks1 = marks
print(marks1.name)
print(marks1.score)
# Out:
# sandhya
# 89

# %%
class book:
    brand = "tech"
    pages = "300"

book1 = book
print(book1.brand)
print(book1.pages)
# Out:
# tech
# 300

# %%
class college:
    name = "AWDC"
    location = "karimnagar"
    course = "BSc ,BBA ,Bcom"

college1 = college
print(college1.name)
print(college1.location)
print(college1.course)
# Out:
# AWDC
# karimnagar
# BSc ,BBA ,Bcom

# %%
class Student:
    def __init__(self ,name ,age):
     self.name = name
     self.age = age

s1 = Student("madhu",20)
print(s1.name)
# Out:
# madhu

# %%
class student:
    def __init__(self ,name ,age):
        self.name = name
        self.age = age

s1 = Student("cherry",20)
print(s1.name)
print(s1.age)
# Out:
# cherry
# 20

# %%
class student:
    def __init__(self ,name ,age ,study):
        self.name = name
        self.age = age
        self.study = study

s1 = student("madhu",20,"bsc")
print(s1.name)
print(s1.age)
print(s1.study)
# Out:
# madhu
# 20
# bsc

# %%
class College:
    def __init__(self ,name ,course ,fee):
        self.name = name
        self.course = course
        self.fee = fee

s1 = College("alphores","bsc",50000)
print(s1.name)
print(s1.course)
print(s1.fee)
# Out:
# alphores
# bsc
# 50000

# %%
class student:
    def __init__(self ,name,course):
        self.name = name
        self.course = course

s1 = student("madhu",",bsc final year")
s2 = student("cherry",",bcom final year")
s3 = student("sandhya",",bba final year")
s4 = student("sweety",",aiml final year")
print(s1.name,s1.course)
print(s2.name,s2.course)
print(s3.name,s3.course)
print(s4.name,s4.course)
# Out:
# madhu ,bsc final year
# cherry ,bcom final year
# sandhya ,bba final year
# sweety ,aiml final year
